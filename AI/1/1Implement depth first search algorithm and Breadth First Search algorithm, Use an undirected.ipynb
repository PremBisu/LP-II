# %% [markdown]
# 1. Implement depth first search algorithm and Breadth First Search algorithm, Use an undirected
# graph and develop a recursive algorithm for searching all the vertices of a graph or tree data
# structure.

# %%
from collections import deque
import networkx as nx
import matplotlib.pyplot as plt

# BFS function
def bfs(graph, start):
    visited = set()
    queue = deque([start])
    bfs_result = []  # To store the BFS result

    print("\nStarting BFS traversal:")
    
    while queue:
        node = queue.popleft()
        if node not in visited:
            visited.add(node)
            bfs_result.append(node)
            print(f"Visited: {node}")
            
            # Queue the neighbors of the current node
            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)
            print(f"Queue after visiting {node}: {list(queue)}")

    return bfs_result

# DFS function
def dfs(graph, start):
    visited = set()
    stack = [start]
    dfs_result = []  # To store the DFS result

    print("\nStarting DFS traversal:")
    
    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            dfs_result.append(node)
            print(f"Visited: {node}")
            
            # Push the neighbors to the stack (in reverse order for correct traversal)
            for neighbor in reversed(graph[node]):
                if neighbor not in visited:
                    stack.append(neighbor)
            print(f"Stack after visiting {node}: {list(stack)}")
    
    return dfs_result

# Input function to create a graph
def input_graph():
    graph = {}
    num_edges = int(input("Enter the number of edges in the graph: "))
    
    print("Enter edges in the format: U V: ")
    for _ in range(num_edges):
        node1, node2 = input().split()
        if node1 not in graph:
            graph[node1] = []
        if node2 not in graph:
            graph[node2] = []
        graph[node1].append(node2)
        graph[node2].append(node1)
    
    return graph

# Function to display the graph
def display_graph(graph):
    print("\nGraph representation:")
    for node, neighbors in graph.items():
        print(f"{node}: {neighbors}")

# Function to visualize the graph
def visualize_graph(graph):
    G = nx.Graph()
    for node, neighbors in graph.items():
        for neighbor in neighbors:
            G.add_edge(node, neighbor)

    # Draw the graph using matplotlib
    plt.figure(figsize=(8, 6))
    nx.draw(G, with_labels=True, node_color='skyblue', node_size=3000, font_size=15, font_weight='bold', edge_color='gray')
    plt.title("Graph Visualization")
    plt.show()

# Main function
if __name__ == "__main__":
    print("Graph Traversal Program (BFS and DFS)")
    
    # Input graph from the user
    graph = input_graph()
    
    # Display graph structure
    display_graph(graph)
    
    # Visualize the graph
    visualize_graph(graph)
    
    # starting node input
    start_node = input("Enter the starting node for BFS and DFS: ")
    
    # BFS and result
    bfs_result = bfs(graph, start_node)
    print(f"\nFinal BFS Traversal Order: {bfs_result}")
    
    # DFS and result
    dfs_result = dfs(graph, start_node)
    print(f"\nFinal DFS Traversal Order: {dfs_result}")
# Out:
# Graph Traversal Program (BFS and DFS)
# Enter edges in the format: U V:
#
# Graph representation:
# A: ['B', 'C']
# B: ['A', 'C', 'E']
# C: ['A', 'B', 'F']
# E: ['B', 'F']
# F: ['C', 'E']
# Starting BFS traversal:
# Visited: A
# Queue after visiting A: ['B', 'C']
# Visited: B
# Queue after visiting B: ['C', 'C', 'E']
# Visited: C
# Queue after visiting C: ['C', 'E', 'F']
# Visited: E
# Queue after visiting E: ['F', 'F']
# Visited: F
# Queue after visiting F: ['F']
#
# Final BFS Traversal Order: ['A', 'B', 'C', 'E', 'F']
#
# Starting DFS traversal:
# Visited: A
# Stack after visiting A: ['C', 'B']
# Visited: B
# Stack after visiting B: ['C', 'E', 'C']
# Visited: C
# Stack after visiting C: ['C', 'E', 'F']
# Visited: F
# Stack after visiting F: ['C', 'E', 'E']
# Visited: E
# Stack after visiting E: ['C', 'E']
#
# Final DFS Traversal Order: ['A', 'B', 'C', 'F', 'E']

# %% [markdown]
# Inputs
#
# 6
#
# A B
# A C
# B C
# B E
# C F
# E F
#
# A
# ________________________________________
# Title: Implementation of Depth First Search (DFS) and Breadth First Search (BFS) for an Undirected Graph
# ________________________________________
# Theory:
# Graph Traversal:
# Graph traversal refers to the process of visiting each node (vertex) in a graph. Two primary methods of traversal are Breadth-First Search (BFS) and Depth-First Search (DFS).
# ________________________________________
# 1. Breadth-First Search (BFS):
# BFS is an algorithm for traversing or searching tree or graph data structures. It starts at a selected node (usually called the source or starting node) and explores all its neighboring nodes at the current depth before moving on to the nodes at the next level of depth.
# •	Data Structure Used: Queue (FIFO)
# •	Characteristics:
# o	Explores nodes level by level.
# o	Guarantees the shortest path in an unweighted graph.
# o	Suitable for finding the shortest path in terms of the number of edges.
# Algorithm Steps:
# 1.	Initialize a queue and add the starting node.
# 2.	Mark the node as visited.
# 3.	While the queue is not empty:
# o	Dequeue a node.
# o	Visit all unvisited neighbors and enqueue them.
# ________________________________________
# 2. Depth-First Search (DFS):
# DFS is another algorithm used to traverse or search through graph data structures. It starts at the root node and explores as far as possible along each branch before backtracking.
# •	Data Structure Used: Stack (LIFO) or Recursion
# •	Characteristics:
# o	Explores nodes deeply before backtracking.
# o	Does not guarantee the shortest path.
# o	Suitable for path finding and topological sorting.
# Algorithm Steps:
# 1.	Initialize a stack and push the starting node.
# 2.	Mark the node as visited.
# 3.	While the stack is not empty:
# o	Pop a node.
# o	Visit all unvisited neighbors and push them onto the stack.
# ________________________________________
# Graph Representation:
# •	The graph is represented using an adjacency list, which is implemented using a dictionary in Python.
# •	The graph is undirected, meaning if there is an edge from node A to B, there's also an edge from B to A.
# ________________________________________
# Visualization:
# •	The graph is visualized using the NetworkX and Matplotlib libraries.
# •	Nodes are displayed with their connections, helping to visually verify the structure and connectivity.
# ________________________________________
# Applications:
# •	BFS is used in shortest path algorithms, peer-to-peer networks, GPS navigation, etc.
# •	DFS is used in solving puzzles, pathfinding, topological sorting, and detecting cycles in graphs.
# ________________________________________
# Conclusion:
# Both BFS and DFS are essential techniques for exploring graphs. BFS is effective for level-wise traversal and shortest path search in unweighted graphs, while DFS is useful for exhaustive path search and backtracking scenarios.
# ________________________________________

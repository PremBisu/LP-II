# %% [markdown]
# * Name: Abhishek Doke
# * Roll No: 13142
# * Div & Batch: A - A2

# %%
import difflib

def welcome():
    print("****** Welcome to Food Shop, I am Abhishek created by Abhishek ******")
    print("I'm here to help you with your order! 😊")
    print()

def info():
    global name
    name = input("Can I know your good name: ")
    print(f"Hey {name}! Good to see you here!!!")
    print("You're in the right place. I will help you book your dish and drinks.")
    print()

def menu():
    print('''Here is your menu with their prices:
    1. Pizza - ₹200
    2. Mango Juice - ₹70
    3. Apple Juice - ₹80
    ''')

def find_closest_match(user_input, menu_items):
    """Function to find closest match for the user input using difflib"""
    closest_match = difflib.get_close_matches(user_input, menu_items, n=1)
    return closest_match[0] if closest_match else None

def order(price, product):
    print("\nThank you for choosing " + product)
    print("\nPlease give us some more information about you!!!!")
    mob = input("Enter your mobile number: ")
    add = input("Enter your address of delivery: ")

    print('''Choose mode of payment:
    1. Online
    2. Cash on delivery
    ''')

    pay = input("Enter your choice: ")
    paymode = "Online" if pay == "1" else "Cash on delivery"

    print("\n******* Here is the detail of your selected order *******")
    print(f"Customer Name  : {name}")
    print(f"Product Name   : {product}")
    print(f"Price          : ₹{price}")
    print(f"Payment Mode   : {paymode}")
    print(f"Delivery Addr  : {add}\n")

    b = input("Please confirm by pressing 1, or 0 to cancel: ")
    if b == "1":
        print("\n******* Your order is booked successfully *******")
        print(f"Customer Name  : {name}")
        print(f"Product Name   : {product}")
        print(f"Price          : ₹{price}")
        print(f"Payment Mode   : {paymode}")
        print(f"Delivery Addr  : {add}")
        print("\nThank you for your order !!! Have a nice day !!!")
    else:
        print("\n***** Thank you for visiting !!! Have a nice day !!! *****")

def choice():
    order_again = True
    total_price = 0
    ordered_items = []

    menu_items = ['pizza', 'mango juice', 'apple juice']
    item_prices = {
        'pizza': 200,
        'mango juice': 70,
        'apple juice': 80
    }

    while order_again:
        print("\nPlease select a product you wish to order (type 'exit' to finish):")
        print("1. Pizza")
        print("2. Mango Juice")
        print("3. Apple Juice")

        product_choice = input("Enter the number corresponding to your choice: ").strip()

        if product_choice == "exit":
            break

        # Map number input to product name
        if product_choice == "1":
            product = "pizza"
            price = item_prices["pizza"]
        elif product_choice == "2":
            product = "mango juice"
            price = item_prices["mango juice"]
        elif product_choice == "3":
            product = "apple juice"
            price = item_prices["apple juice"]
        else:
            print("Invalid choice. Please choose a valid product number (1, 2, or 3).")
            continue

        ordered_items.append(product.title())
        total_price += price
        print(f"Adding {product.title()} to your order!")

        more = input("\nWould you like to order something else? (yes/no): ").strip().lower()
        if more != "yes":
            order_again = False

    if ordered_items:
        print(f"\nYour ordered items: {', '.join(ordered_items)}")
        print(f"Total price: ₹{total_price}")
        confirm_order = input("Would you like to confirm your order? (yes/no): ").strip().lower()
        if confirm_order == "yes":
            print("\nLet's proceed with your details:")
            order(total_price, ", ".join(ordered_items))
        else:
            print("\nThank you for visiting! Have a nice day.")
    else:
        print("\nNo items selected. Thank you for visiting! Have a nice day.")

# Run the app
welcome()
info()
menu()
choice()
# Out:
# ****** Welcome to Food Shop, I am Abhishek created by Abhishek ******
# I'm here to help you with your order! 😊
#
# Hey Abhi! Good to see you here!!!
# You're in the right place. I will help you book your dish and drinks.
#
# Here is your menu with their prices:
#     1. Pizza - ₹200
#     2. Mango Juice - ₹70
#     3. Apple Juice - ₹80
#
#
# Please select a product you wish to order (type 'exit' to finish):
# 1. Pizza
# 2. Mango Juice
# 3. Apple Juice
# Adding Pizza to your order!
#
# Please select a product you wish to order (type 'exit' to finish):
# 1. Pizza
# 2. Mango Juice
# 3. Apple Juice
# Adding Mango Juice to your order!
#
# Please select a product you wish to order (type 'exit' to finish):
# 1. Pizza
# 2. Mango Juice
# 3. Apple Juice
#
# Your ordered items: Pizza, Mango Juice
# Total price: ₹270
#
# Let's proceed with your details:
#
# Thank you for choosing Pizza, Mango Juice
#
# Please give us some more information about you!!!!
# Choose mode of payment:
#     1. Online
# ...

# %% [markdown]
# ________________________________________
# 5. Develop an Elementary Chatbot for Any Suitable Customer Interaction Application
# 📌 Introduction
# A chatbot is a software application designed to simulate human conversation through text or voice interactions. It can assist users by answering queries, providing information, or performing simple tasks automatically. Chatbots are widely used in customer interaction applications to enhance user experience, automate repetitive queries, and provide 24/7 support.
# ________________________________________
# 💡 Objective
# To design and develop a basic chatbot capable of handling elementary customer queries for a specific domain (e.g., hotel booking, e-commerce, technical support, or banking). The chatbot will use predefined rules or simple natural language processing techniques to respond to user inputs.
# ________________________________________
# 🛠️ Architecture of an Elementary Chatbot
# 1.	User Interface (Frontend)
# o	A chat window or form where users input their queries
# o	Technologies: HTML, CSS, JavaScript (or integrated into platforms like Telegram, Messenger, or WhatsApp)
# 2.	Processing Engine (Backend)
# o	Takes user input and processes it to determine intent and generate a response
# o	Technologies: Python (Flask), Node.js, or other server-side platforms
# 3.	Knowledge Base / Rule Engine
# o	Contains predefined responses based on keywords or intents
# o	Example: If user types "What are your working hours?", reply with "We’re open 9 AM to 6 PM, Monday to Friday."
# 4.	Response Generator
# o	Returns the appropriate answer from the rule set or logic to the user via frontend
# ________________________________________
# 🧠 Types of Elementary Chatbots
# 1.	Rule-Based Chatbots
# o	Follow a tree of if-else statements
# o	Limited to predefined questions and answers
# o	Simple, fast, but not flexible
# 2.	Keyword-Based Chatbots
# o	Search for specific keywords in user input and match them to responses
# o	Slightly more flexible than rule-based bots
# 3.	AI-Based (Elementary Level)
# o	Use lightweight NLP libraries (e.g., NLTK or spaCy in Python)
# o	Basic intent recognition, tokenization, and matching
# ________________________________________
# 💬 Example Use Case: E-commerce Customer Support Chatbot
# Sample Dialog:
# •	User: "Where is my order?"
# •	Bot: "Please enter your order ID so I can help track it."
# •	User: "What is your return policy?"
# •	Bot: "You can return items within 10 days of delivery. Want to initiate a return?"
# ________________________________________
# 🛑 Limitations of Elementary Chatbots
# •	Cannot handle complex language or ambiguous questions
# •	Restricted to fixed responses and predefined intents
# •	No learning or context awareness over conversations
# ________________________________________
# 🧪 Technologies Used
# Component	Tools/Tech
# Frontend	HTML, CSS, JavaScript, Bootstrap
# Backend	Python (Flask) / Node.js
# Logic/Rules	Python conditions or JSON mappings
# NLP (optional)	NLTK, spaCy (for basic parsing)
# Hosting	Localhost or cloud (Render, Heroku)
# ________________________________________
# ✅ Advantages of Using Chatbots for Customer Interaction
# •	24/7 availability
# •	Instant response to queries
# •	Reduces burden on human agents
# •	Improves customer satisfaction
# •	Scalability with minimal cost
# ________________________________________
# 📌 Conclusion
# Developing an elementary chatbot is a stepping stone into the world of conversational AI. Though limited in scope, such bots can significantly enhance customer interaction by automating basic queries. They also provide a practical foundation for building more intelligent AI-driven conversational agents in the future.
# ________________________________________
